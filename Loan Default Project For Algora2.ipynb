# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
#let import the dataset
filepath = r"C:\Users\DELL\OneDrive\Documents\Loan_default.csv\Loan_default.csv"
df = pd.read_csv(filepath)

# %%
df.head(15)
# Out:
#         LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0   I38PQUQS96   56   85994       50587          520              80
# 1   HPSK72WA7R   69   50432      124440          458              15
# 2   C1OZ6DPJ8Y   46   84208      129188          451              26
# 3   V2KKSFM3UN   32   31713       44799          743               0
# 4   EY08JDHTZP   60   20437        9139          633               8
# 5   A9S62RQ7US   25   90298       90448          720              18
# 6   H8GXPAOS71   38  111188      177025          429              80
# 7   0HGZQKJ36W   56  126802      155511          531              67
# 8   1R0N3LGNRJ   36   42053       92357          827              83
# 9   CM9L1GTT2P   40  132784      228510          480             114
# 10  IA35XVH6ZO   28  140466      163781          652              94
# 11  Y8UETC3LSG   28  149227      139759          375              56
# 12  RM6QSRHIYP   41   23265       63527          829              87
# 13  GX5YQOGROM   53  117550       95744          395             112
# 14  X0BVPZLDC0   57  139699       88143          635             112
#
#     NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                4         15.23        36      0.44   Bachelor's
# 1                1          4.81        60      0.68     Master's
# 2                3         21.17        24      0.31     Master's
# 3                3          7.07        24      0.23  High School
# 4                4          6.51        48      0.73   Bachelor's
# 5                2         22.72        24      0.10  High School
# 6                1         19.11        12      0.16   Bachelor's
# 7                4          8.15        60      0.43          PhD
# 8                1         23.94        48      0.20   Bachelor's
# 9                4          9.09        48      0.33  High School
# 10               2          9.08        48      0.23  High School
# 11               3          5.84        36      0.80          PhD
# 12               4          9.73        60      0.45     Master's
# 13               4          3.58        24      0.73  High School
# 14               4          5.63        48      0.20     Master's
#
#    EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0       Full-time      Divorced         Yes           Yes       Other
# 1       Full-time       Married          No            No       Other
# 2      Unemployed      Divorced         Yes           Yes        Auto
# 3       Full-time       Married          No            No    Business
# 4      Unemployed      Divorced          No           Yes        Auto
# 5      Unemployed        Single         Yes            No    Business
# 6      Unemployed        Single         Yes            No        Home
# 7       Full-time       Married          No            No        Home
# 8   Self-employed      Divorced         Yes            No   Education
# 9   Self-employed       Married         Yes            No       Other
# 10     Unemployed       Married          No            No   Education
# 11      Full-time      Divorced          No            No   Education
# 12      Full-time      Divorced         Yes            No        Auto
# 13     Unemployed        Single          No            No        Auto
# 14      Part-time      Divorced          No            No        Home
#
#    HasCoSigner  Default
# 0          Yes        0
# 1          Yes        0
# 2           No        1
# 3           No        0
# 4           No        0
# 5          Yes        1
# 6          Yes        0
# 7          Yes        0
# 8           No        1
# 9          Yes        0
# 10          No        0
# 11         Yes        1
# 12         Yes        0
# 13         Yes        0
# 14          No        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 18 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   LoanID          255347 non-null  object
#  1   Age             255347 non-null  int64
#  2   Income          255347 non-null  int64
#  3   LoanAmount      255347 non-null  int64
#  4   CreditScore     255347 non-null  int64
#  5   MonthsEmployed  255347 non-null  int64
#  6   NumCreditLines  255347 non-null  int64
#  7   InterestRate    255347 non-null  float64
#  8   LoanTerm        255347 non-null  int64
#  9   DTIRatio        255347 non-null  float64
#  10  Education       255347 non-null  object
#  11  EmploymentType  255347 non-null  object
#  12  MaritalStatus   255347 non-null  object
#  13  HasMortgage     255347 non-null  object
#  14  HasDependents   255347 non-null  object
#  15  LoanPurpose     255347 non-null  object
#  16  HasCoSigner     255347 non-null  object
#  17  Default         255347 non-null  int64
# dtypes: float64(2), int64(8), object(8)
# memory usage: 35.1+ MB

# %%
df.shape
# Out:
# (255347, 18)

# %%
df.isnull().sum()
# Out:
# LoanID            0
# Age               0
# Income            0
# LoanAmount        0
# CreditScore       0
# MonthsEmployed    0
# NumCreditLines    0
# InterestRate      0
# LoanTerm          0
# DTIRatio          0
# Education         0
# EmploymentType    0
# MaritalStatus     0
# HasMortgage       0
# HasDependents     0
# LoanPurpose       0
# HasCoSigner       0
# Default           0
# dtype: int64

# %%
#inspecting the column
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner',
#        'Default'],
#       dtype='object')

# %% [markdown]
# #### Checking for Outlier

# %%
#let check for outlier

Num = ['Age', 'Income', 'LoanAmount', 'CreditScore',
       'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
       'DTIRatio','Default']

df[Num].plot(
    kind = 'box',
    figsize = (20, 4),
    subplots = True
);

# %%
df.describe().transpose()
# Out:
#                    count           mean           std      min       25%  \
# Age             255347.0      43.498306     14.990258     18.0     31.00
# Income          255347.0   82499.304597  38963.013729  15000.0  48825.50
# LoanAmount      255347.0  127578.865512  70840.706142   5000.0  66156.00
# CreditScore     255347.0     574.264346    158.903867    300.0    437.00
# MonthsEmployed  255347.0      59.541976     34.643376      0.0     30.00
# NumCreditLines  255347.0       2.501036      1.117018      1.0      2.00
# InterestRate    255347.0      13.492773      6.636443      2.0      7.77
# LoanTerm        255347.0      36.025894     16.969330     12.0     24.00
# DTIRatio        255347.0       0.500212      0.230917      0.1      0.30
# Default         255347.0       0.116128      0.320379      0.0      0.00
#
#                       50%        75%       max
# Age                 43.00      56.00      69.0
# Income           82466.00  116219.00  149999.0
# LoanAmount      127556.00  188985.00  249999.0
# CreditScore        574.00     712.00     849.0
# MonthsEmployed      60.00      90.00     119.0
# NumCreditLines       2.00       3.00       4.0
# InterestRate        13.46      19.25      25.0
# LoanTerm            36.00      48.00      60.0
# DTIRatio             0.50       0.70       0.9
# Default              0.00       0.00       1.0

# %% [markdown]
# #### From the above data i notice there is no missing value
# #### Just 1 Outlier in the Default column which i know will not affect my model
# #### The data is clean and we can proceed to analysis

# %% [markdown]
# ### Classification Of Age for Analysis Purpose

# %%
def age_convert(Age):
    ageCategory=[]
    for i in Age:
        if i <= 30:
            ageCategory.append('Age 18-30')
        elif i <= 40:
            ageCategory.append('Age 31-40')
        elif i <= 50:
            ageCategory.append('Age 41-50')
        elif i <= 60:
            ageCategory.append('Age 51-60')
        else:
            ageCategory.append('Above 60')
            
    return ageCategory

# %%
df['Age_Category']=age_convert(df['Age'])

# %%
df.head(12)
# Out:
#         LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 0   I38PQUQS96   56   85994       50587          520              80
# 1   HPSK72WA7R   69   50432      124440          458              15
# 2   C1OZ6DPJ8Y   46   84208      129188          451              26
# 3   V2KKSFM3UN   32   31713       44799          743               0
# 4   EY08JDHTZP   60   20437        9139          633               8
# 5   A9S62RQ7US   25   90298       90448          720              18
# 6   H8GXPAOS71   38  111188      177025          429              80
# 7   0HGZQKJ36W   56  126802      155511          531              67
# 8   1R0N3LGNRJ   36   42053       92357          827              83
# 9   CM9L1GTT2P   40  132784      228510          480             114
# 10  IA35XVH6ZO   28  140466      163781          652              94
# 11  Y8UETC3LSG   28  149227      139759          375              56
#
#     NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 0                4         15.23        36      0.44   Bachelor's
# 1                1          4.81        60      0.68     Master's
# 2                3         21.17        24      0.31     Master's
# 3                3          7.07        24      0.23  High School
# 4                4          6.51        48      0.73   Bachelor's
# 5                2         22.72        24      0.10  High School
# 6                1         19.11        12      0.16   Bachelor's
# 7                4          8.15        60      0.43          PhD
# 8                1         23.94        48      0.20   Bachelor's
# 9                4          9.09        48      0.33  High School
# 10               2          9.08        48      0.23  High School
# 11               3          5.84        36      0.80          PhD
#
#    EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 0       Full-time      Divorced         Yes           Yes       Other
# 1       Full-time       Married          No            No       Other
# 2      Unemployed      Divorced         Yes           Yes        Auto
# 3       Full-time       Married          No            No    Business
# 4      Unemployed      Divorced          No           Yes        Auto
# 5      Unemployed        Single         Yes            No    Business
# 6      Unemployed        Single         Yes            No        Home
# 7       Full-time       Married          No            No        Home
# 8   Self-employed      Divorced         Yes            No   Education
# 9   Self-employed       Married         Yes            No       Other
# 10     Unemployed       Married          No            No   Education
# 11      Full-time      Divorced          No            No   Education
#
#    HasCoSigner  Default Age_Category
# 0          Yes        0    Age 51-60
# 1          Yes        0     Above 60
# 2           No        1    Age 41-50
# 3           No        0    Age 31-40
# 4           No        0    Age 51-60
# 5          Yes        1    Age 18-30
# 6          Yes        0    Age 31-40
# 7          Yes        0    Age 51-60
# 8           No        1    Age 31-40
# 9          Yes        0    Age 31-40
# 10          No        0    Age 18-30
# 11         Yes        1    Age 18-30

# %% [markdown]
# ## Let conduct some analysis with the categorical data with respect to Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'Age_Category')
plt.xlabel('Age_Category')
plt.ylabel('Count')
plt.title('Age by Category');

# %% [markdown]
# ### Age_Category by Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'Age_Category', hue = 'Default')
plt.xlabel('Age_Category')
plt.ylabel('Count')
plt.title('Age_Category By Default')

df['Age_Category'].value_counts()
# Out:
# Age 18-30    63577
# Age 31-40    49593
# Age 41-50    49003
# Age 51-60    48972
# Above 60     44202
# Name: Age_Category, dtype: int64

# %% [markdown]
# ### Education Category by Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'Education', hue = 'Default')
plt.xlabel('Education')
plt.ylabel('Count')
plt.title('Education by Default')

df['Education'].value_counts()
# Out:
# Bachelor's     64366
# High School    63903
# Master's       63541
# PhD            63537
# Name: Education, dtype: int64

# %% [markdown]
# ### Marital Status By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'MaritalStatus', hue = 'Default')
plt.xlabel('MaritalStatus')
plt.ylabel('Count')
plt.title('MaritalStatus by Default')

df['MaritalStatus'].value_counts()
# Out:
# Married     85302
# Divorced    85033
# Single      85012
# Name: MaritalStatus, dtype: int64

# %% [markdown]
# ### Employment Type By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'EmploymentType', hue = 'Default')
plt.xlabel('EmploymentType')
plt.ylabel('Count')
plt.title('EmploymentType By Default')

df['EmploymentType'].value_counts()
# Out:
# Part-time        64161
# Unemployed       63824
# Self-employed    63706
# Full-time        63656
# Name: EmploymentType, dtype: int64

# %% [markdown]
# ### Those that Has Mortgage By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'HasMortgage', hue = 'Default')
plt.xlabel('HasMortgage')
plt.ylabel('Count')
plt.title('HasMortgage By Default')

df['HasMortgage'].value_counts()
# Out:
# Yes    127677
# No     127670
# Name: HasMortgage, dtype: int64

# %% [markdown]
# ### Those that Has Dependents By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'HasDependents', hue = 'Default')
plt.xlabel('HasDependents')
plt.ylabel('Count')
plt.title('HasDependents By Default')

df['HasDependents'].value_counts()
# Out:
# Yes    127742
# No     127605
# Name: HasDependents, dtype: int64

# %% [markdown]
# ### Purpose of Loan By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'LoanPurpose', hue = 'Default')
plt.xlabel('LoanPurpose')
plt.ylabel('Count')
plt.title('Loan Purpose by Default')

df['LoanPurpose'].value_counts()
# Out:
# Business     51298
# Home         51286
# Education    51005
# Other        50914
# Auto         50844
# Name: LoanPurpose, dtype: int64

# %% [markdown]
# ### Those that Has Cosigner By Default

# %%
plt.figure(
    figsize=(10,5)
)
sns.countplot(data = df, x = 'HasCoSigner', hue = 'Default')
plt.xlabel('HasCosigner')
plt.ylabel('Count')
plt.title('HasCosigner By Default')

df['HasCoSigner'].value_counts()
# Out:
# Yes    127701
# No     127646
# Name: HasCoSigner, dtype: int64

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# #### Encoding of Categorical/Binary Data

# %%
df.columns
# Out:
# Index(['LoanID', 'Age', 'Income', 'LoanAmount', 'CreditScore',
#        'MonthsEmployed', 'NumCreditLines', 'InterestRate', 'LoanTerm',
#        'DTIRatio', 'Education', 'EmploymentType', 'MaritalStatus',
#        'HasMortgage', 'HasDependents', 'LoanPurpose', 'HasCoSigner', 'Default',
#        'Age_Category'],
#       dtype='object')

# %%
# I have to drop colunm not needed for my model
df.drop(['LoanID', 'Age_Category'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio    Education EmploymentType MaritalStatus  \
# 0         15.23        36      0.44   Bachelor's      Full-time      Divorced
# 1          4.81        60      0.68     Master's      Full-time       Married
# 2         21.17        24      0.31     Master's     Unemployed      Divorced
# 3          7.07        24      0.23  High School      Full-time       Married
# 4          6.51        48      0.73   Bachelor's     Unemployed      Divorced
#
#   HasMortgage HasDependents LoanPurpose HasCoSigner  Default
# 0         Yes           Yes       Other         Yes        0
# 1          No            No       Other         Yes        0
# 2         Yes           Yes        Auto          No        1
# 3          No            No    Business          No        0
# 4          No           Yes        Auto          No        0

# %%
# encoding Binary Data map
df['HasMortgage'] = df['HasMortgage'].map({'Yes': 1, 'No': 0})
df['HasDependents'] = df['HasDependents'].map({'Yes': 1, 'No': 0})
df['HasCoSigner'] = df['HasCoSigner'].map({'Yes': 1, 'No': 0})

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = LabelEncoder()
df['Education'] = label_encoder.fit_transform(df['Education'])
df['EmploymentType'] = label_encoder.fit_transform(df['EmploymentType'])
df['MaritalStatus'] = label_encoder.fit_transform(df['MaritalStatus'])
df['LoanPurpose'] = label_encoder.fit_transform(df['LoanPurpose'])

# %%
df.head()
# Out:
#    Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0   56   85994       50587          520              80               4
# 1   69   50432      124440          458              15               1
# 2   46   84208      129188          451              26               3
# 3   32   31713       44799          743               0               3
# 4   60   20437        9139          633               8               4
#
#    InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  MaritalStatus  \
# 0         15.23        36      0.44          0               0              0
# 1          4.81        60      0.68          2               0              1
# 2         21.17        24      0.31          2               3              0
# 3          7.07        24      0.23          1               0              1
# 4          6.51        48      0.73          0               3              0
#
#    HasMortgage  HasDependents  LoanPurpose  HasCoSigner  Default
# 0            1              1            4            1        0
# 1            0              0            4            1        0
# 2            1              1            0            0        1
# 3            0              0            1            0        0
# 4            0              1            0            0        0

# %%
#using get_dummies to create my feature and label
#X=pd.get_dummies(df.drop("Default", axis=1),drop_first=True, dtype="int")

# %%
X = df.drop('Default', axis = 1,)
y = df["Default"]

# %%
X.head(15)
# Out:
#     Age  Income  LoanAmount  CreditScore  MonthsEmployed  NumCreditLines  \
# 0    56   85994       50587          520              80               4
# 1    69   50432      124440          458              15               1
# 2    46   84208      129188          451              26               3
# 3    32   31713       44799          743               0               3
# 4    60   20437        9139          633               8               4
# 5    25   90298       90448          720              18               2
# 6    38  111188      177025          429              80               1
# 7    56  126802      155511          531              67               4
# 8    36   42053       92357          827              83               1
# 9    40  132784      228510          480             114               4
# 10   28  140466      163781          652              94               2
# 11   28  149227      139759          375              56               3
# 12   41   23265       63527          829              87               4
# 13   53  117550       95744          395             112               4
# 14   57  139699       88143          635             112               4
#
#     InterestRate  LoanTerm  DTIRatio  Education  EmploymentType  \
# 0          15.23        36      0.44          0               0
# 1           4.81        60      0.68          2               0
# 2          21.17        24      0.31          2               3
# 3           7.07        24      0.23          1               0
# 4           6.51        48      0.73          0               3
# 5          22.72        24      0.10          1               3
# 6          19.11        12      0.16          0               3
# 7           8.15        60      0.43          3               0
# 8          23.94        48      0.20          0               2
# 9           9.09        48      0.33          1               2
# 10          9.08        48      0.23          1               3
# 11          5.84        36      0.80          3               0
# 12          9.73        60      0.45          2               0
# 13          3.58        24      0.73          1               3
# 14          5.63        48      0.20          2               1
#
#     MaritalStatus  HasMortgage  HasDependents  LoanPurpose  HasCoSigner
# 0               0            1              1            4            1
# 1               1            0              0            4            1
# 2               0            1              1            0            0
# 3               1            0              0            1            0
# 4               0            0              1            0            0
# 5               2            1              0            1            1
# 6               2            1              0            3            1
# 7               1            0              0            3            1
# 8               0            1              0            2            0
# 9               1            1              0            4            1
# 10              1            0              0            2            0
# 11              0            0              0            2            1
# 12              0            1              0            0            1
# 13              2            0              0            0            1
# 14              0            0              0            3            0

# %% [markdown]
# ##### we have successful split our data into features and target (X,y)

# %%
y.head()
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    0
# Name: Default, dtype: int64

# %%
y.value_counts()
# Out:
# 0    225694
# 1     29653
# Name: Default, dtype: int64

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255347 entries, 0 to 255346
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Age             255347 non-null  int64
#  1   Income          255347 non-null  int64
#  2   LoanAmount      255347 non-null  int64
#  3   CreditScore     255347 non-null  int64
#  4   MonthsEmployed  255347 non-null  int64
#  5   NumCreditLines  255347 non-null  int64
#  6   InterestRate    255347 non-null  float64
#  7   LoanTerm        255347 non-null  int64
#  8   DTIRatio        255347 non-null  float64
#  9   Education       255347 non-null  int32
#  10  EmploymentType  255347 non-null  int32
#  11  MaritalStatus   255347 non-null  int32
#  12  HasMortgage     255347 non-null  int64
#  13  HasDependents   255347 non-null  int64
#  14  LoanPurpose     255347 non-null  int32
#  15  HasCoSigner     255347 non-null  int64
# dtypes: float64(2), int32(4), int64(10)
# memory usage: 27.3 MB

# %%
# let check if our label is balance 
y.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ##### We are going to use SMOTE Over_sampling to balance our data

# %%
#let use overstampling to balance the target data
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.combine import SMOTETomek

# %%
#smote = SMOTE(sampling_strategy = 'auto', random_state = 42)

# %%
smt = SMOTETomek(random_state=42)

# %%
X_res, y_res = smt.fit_resample(X, y)

# %%
#ros = RandomOverSampler(random_state=42)

# %%
#X_res, y_res = ros.fit_resample(X, y)

# %%
y_res.value_counts()
# Out:
# 0    209556
# 1    209556
# Name: Default, dtype: int64

# %%
y_res.value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# #### Let prepare our data for modelling
# ###### let split our data into Train and Test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X_res, y_res, test_size=0.3, random_state=42)

# %%
print(X_train.shape)
print(X_res.shape)
# Out:
# (293378, 16)
# (419112, 16)

# %%
print(y_train.shape)
print(y_res.shape)
# Out:
# (293378,)
# (419112,)

# %%
#let scale our data
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_test=scaler.transform(X_test)

# %% [markdown]
# #### Model Creation

# %% [markdown]
# ##### RandomForestClassifier

# %%
#let import the library
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,precision_score,balanced_accuracy_score,average_precision_score,f1_score,recall_score
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
rfc_model = RandomForestClassifier()

# %%
def check_model(model):
    model.fit(X_train,y_train)
    y_pred = model.predict(X_test)
    ACCURACY = accuracy_score(y_test,y_pred)
    PRE_SCORE = precision_score(y_test,y_pred)
    RECALL_SCORE = recall_score(y_test,y_pred)
    F1 = f1_score(y_test,y_pred)
    print("ACCURACY is", ACCURACY)
    print("PRE_SCORE is", PRE_SCORE)
    print("RECALL_SCORE is", RECALL_SCORE)
    print("F1_Score is", F1)

# %% [markdown]
# ### RandomForestClassifier

# %%
check_model(rfc_model)
# Out:
# ACCURACY is 0.87716926209299
# PRE_SCORE is 0.8974708465848856
# RECALL_SCORE is 0.8508255563531946
# F1_Score is 0.8735259433962266

# %% [markdown]
# ##### SVM

# %%
#from sklearn import svm

# %%
#svc_model = svm.SVC()

# %% [markdown]
# #### PassiveAggressiveClassifier

# %%
#from sklearn.linear_model import PassiveAggressiveClassifier

# %%
#PAC = PassiveAggressiveClassifier()

# %%
#check_model(PAC)

# %% [markdown]
# #### KNN

# %%
#from sklearn.neighbors import KNeighborsClassifier

# %%
#KNN = KNeighborsClassifier()

# %%
#check_model(KNN)

# %% [markdown]
# #### GaussianProcessClassifier

# %%
#from sklearn.gaussian_process import GaussianProcessClassifier

# %%
#GPC = GaussianProcessClassifier()

# %% [markdown]
# #### DecisionTree

# %%
#from sklearn.tree import DecisionTreeClassifier

# %%
#dt_model = DecisionTreeClassifier()

# %%
#check_model(dt_model)

# %% [markdown]
# #### MLPClassifier

# %%
#from sklearn.neural_network import MLPClassifier

# %%
#MLP_model = MLPClassifier()

# %%
#check_model(MLP_model)

# %% [markdown]
# ### Adaboost

# %%
#from sklearn.ensemble import AdaBoostClassifier

# %%
#Adb_model = AdaBoostClassifier()

# %%
#check_model(Adb_model)

# %% [markdown]
# #### GradientBoostingClassifier

# %%
#from sklearn.ensemble import GradientBoostingClassifier

# %%
#gbc_model = GradientBoostingClassifier()

# %%
#check_model(gbc_model)

# %% [markdown]
# #### ExtraTreesClassifier

# %%
#from sklearn.ensemble import ExtraTreesClassifier

# %%
#etc_model = ExtraTreesClassifier()

# %%
#check_model(etc_model)

# %% [markdown]
# #### From my model selection, i will be using RandomForestClassifier
# #### The Accuracy is good
# #### The F1_score is good
# #### The Recall_score is good
# #### The Precission Score is good

# %% [markdown]
# #### But i will love to improve on my desire model, so i will be introducing GridSearchCV

# %% [markdown]
# ## Using GridSearchCV to improve my model

# %%
#let import GridSearchCV 
#from sklearn.model_selection import GridSearchCV

# %%
#param_grid = {
    #'n_estimators': [50, 100, 200],
    #'max_depth': [None, 10, 20],
    #'min_samples_split': [2, 5, 10],
    #'min_samples_leaf': [1, 2, 4],
    #'max_features': ['auto', 'sqrt', 'log2']
#}

# %%
#grid_model = GridSearchCV(estimator=rfc_model, param_grid=param_grid, cv=3, scoring='accuracy')

# %% [markdown]
# ### Using RandomizedSearchCV to improve on my Model
# ##### Using RandomForest Model

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint

# %%
param_dist = {
    'n_estimators': randint(10, 200),
    'max_features': ['auto', 'sqrt', 'log2', None],
    'max_depth': randint(1, 20),
    'min_samples_split': randint(2, 20),
    'min_samples_leaf': randint(1, 20),
    'bootstrap': [True, False]
}

# %%
random_model = RandomizedSearchCV(
    rfc_model,
    param_distributions=param_dist,
    n_iter=10,                         # Number of parameter settings that are sampled
    scoring='accuracy',                # You can use other scoring metrics
    cv=5,                              # Number of cross-validation folds
    verbose=1,
    n_jobs=-1,                         # Use all available CPUs
    random_state=42                    # Set a random seed for reproducibility
)

# %%
#check_model(random_model)

# %%
random_model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 5 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 5 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 1145, in wrapper
#     estimator._validate_params()
#   File "C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py", line 638, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py", line 96, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestClassifier must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\DELL\AppData\Roaming\Python\Python311\site-packages\sklearn\model_selection\_search.py:979: UserWarning: One or more of the test scores are non-finite: [0.84244899 0.82701498 0.6833573  0.63366717 0.8107186  0.83951762
#         nan 0.79368596 0.67808081 0.80631131]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002051EEBFC50>,
#                                         'max_features': ['auto', 'sqrt', 'log2',
#                                                          None],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x0000020519E32ED0>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002052481C410>,
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x000002051EFA0450>},
#                    random_state=42, scoring='accuracy', verbose=1)

# %%
random_model.best_params_
# Out:
# {'bootstrap': True,
#  'max_depth': 15,
#  'max_features': 'log2',
#  'min_samples_leaf': 8,
#  'min_samples_split': 8,
#  'n_estimators': 131}

# %%
random_model.best_estimator_
# Out:
# RandomForestClassifier(max_depth=15, max_features='log2', min_samples_leaf=8,
#                        min_samples_split=8, n_estimators=131)

# %%
rfc_predict = random_model.predict(X_test)

# %%
rfc_predict
# Out:
# array([1, 0, 1, ..., 1, 0, 0], dtype=int64)

# %%
print(classification_report(y_test, rfc_predict))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85     63049
#            1       0.86      0.83      0.84     62685
#
#     accuracy                           0.85    125734
#    macro avg       0.85      0.85      0.85    125734
# weighted avg       0.85      0.85      0.85    125734

# %%
print(confusion_matrix(y_test,rfc_predict))
# Out:
# [[54297  8752]
#  [10722 51963]]

# %%
accuracy = accuracy_score(y_test, rfc_predict)
bal_accuracy = balanced_accuracy_score(y_test, rfc_predict)
precision_score = average_precision_score(y_test, rfc_predict)
f1 = f1_score(y_test, rfc_predict)
Recall = recall_score(y_test, rfc_predict, average = 'macro')
print(f'The Accuracy is {accuracy:.3f}.')
print(f'The Bal_accuracy is {bal_accuracy:.3f}.')
print(f'The Precision_score is {precision_score:.3f}.')
print(f'The f1_score is {f1:.3f}.')
print(f'The Recall_score is {Recall:.3f}.')
# Out:
# The Accuracy is 0.845.
# The Bal_accuracy is 0.845.
# The Precision_score is 0.795.
# The f1_score is 0.842.
# The Recall_score is 0.845.

# %%
ConfusionMatrixDisplay.from_estimator(random_model,X_test,y_test);

# %%
import joblib

# %%
joblib.dump(random_model, "loan_model_saved")
# Out:
# ['loan_model_saved']

# %%
load_model = joblib.load("loan_model_saved")

# %%
new_result = load_model.predict(X_test)

# %%
new_result
# Out:
# array([1, 0, 1, ..., 1, 0, 0], dtype=int64)
